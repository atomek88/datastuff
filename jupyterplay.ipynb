# %%
# playing inside jupyter
# !echo Hello!!
# Out:
# Hello!!

# %%
#pass var to shell with $ like in CL
message = 'nifty'
# !echo $message
# Out:
# nifty

# %%
# magics (line magic, cell magic)

# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# how often you autosave
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
# show plot images inline within cell outputs
# %matplotlib inline

# %%
# debugging
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-03b9be105f74> in <module>()
# ----> 1 raise NotImplementedError()
#
# NotImplementedError:
# > <ipython-input-9-03b9be105f74>(1)<module>()
# ----> 1 raise NotImplementedError()
#
# ipdb> get_ipython().run_line_magic('pdb','')
# Automatic pdb calling has been turned OFF
# ipdb> get_ipython().run_line_magic('pdb','')
# Automatic pdb calling has been turned ON
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# ipdb> quit

# %%
# %time and %timeit
# %time
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.11 µs

# %%
# %%HTML
# this is<em> really</em> neat!
# Out:
# this is<em> really</em> neat!

# %%
# %%latex
# some important equations:$E = mc^2$
#   $e^{i pi} = -1$
# Out:
# some important equations:$E = mc^2$
#   $e^{i pi} = -1$

# %%
# configure logging
import logging
logging.error("jupyter can highlight stuff for you")
# Out:
# ERROR:root:jupyter can highlight stuff for you

# %%
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

logging.info('This is info')
logging.debug('this is debug msg')
# Out:
# INFO:root:This is info
# DEBUG:root:this is debug msg

# %%
handler = logging.StreamHandler()
handler.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(levelname)s: %(message)s')
handler.setFormatter(formatter)

#override
logger.handlers = [handler]

logging.error('An error')
logging.warning('An error')
logging.info('An error')
# Out:
# ERROR: An error
# WARNING: An error
# INFO: An error

# %%
handler = logging.FileHandler(filename='important_log.log', mode='a')

# %%
# can set up macros
# %macro -q __file_handler
# %store __file_handler
# Out:
# UsageError: %macro insufficient args; usage '%macro name n1-n2 n3-4...

# %%
# external code, use to %load in modules to lad script into cell and exec
# %load imports.py

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
pip3 install ipython-sql
# %load_ext sql
# Out:
#   File "<ipython-input-24-128355b6016c>", line 1
#     pip3 install ipython-sql
#                ^
# SyntaxError: invalid syntax
